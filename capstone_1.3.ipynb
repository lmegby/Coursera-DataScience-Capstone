# %% [markdown]
# # Project: Segmenting and Clustering Neighborhoods in Toronto - Boyan Gu

# %% [markdown]
# Load pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Webpage url and extract tables

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
dfs = pd.read_html(url)

# %% [markdown]
# Get the first table and remove rows that 'Borough' are Not assigned

# %%
df = dfs[0]
df.drop(df[df['Borough'] == 'Not assigned'].index, inplace = True)

# %% [markdown]
# Replace the 'Not assigned' Neighbour with the corresponding Borough

# %%
df['Neighbourhood'] = np.where((df.Neighbourhood== 'Not assigned'), df.Borough, df.Neighbourhood)

# %% [markdown]
# Merge rows based on Postal Code

# %%
df.groupby('Postal Code')

# %%
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
print(df.shape)
# Out:
# (103, 3)

# %% [markdown]
# Load lat/lon data

# %%
df2 = pd.read_csv('/Users/boyangu/Desktop/data_science_capstone/Geospatial_Coordinates.csv')

# %% [markdown]
# Add lat/lon data to previous dataframe

# %%
df['Latitude'] = 0
df['Longitude'] = 0
for postal_code in df['Postal Code'].values:
    df['Latitude'] = np.where((df2['Postal Code'].values == postal_code), df2.Latitude, df.Latitude)
    df['Longitude'] = np.where((df2['Postal Code'].values == postal_code), df2.Longitude, df.Longitude)

# %%
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 2                                            Parkwoods  43.806686 -79.194353
# 3                                     Victoria Village  43.784535 -79.160497
# 4                            Regent Park, Harbourfront  43.763573 -79.188711
# 5                     Lawrence Manor, Lawrence Heights  43.770992 -79.216917
# 6          Queen's Park, Ontario Provincial Government  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 160      The Kingsway, Montgomery Road, Old Mill North  43.706876 -79.518188
# 165                               Church and Wellesley  43.696319 -79.532242
# 168  Business reply mail Processing Centre, South C...  43.688905 -79.554724
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.739416 -79.588437
# 178  Mimico NW, The Queensway West, South of Bloor,...  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
import folium

# %% [markdown]
# Select boroughs that contains the word Toronto

# %%
toronto = df[df['Borough'].str.contains('Toronto')]
# Out:
#     Postal Code           Borough  \
# 4           M5A  Downtown Toronto
# 6           M7A  Downtown Toronto
# 13          M5B  Downtown Toronto
# 22          M5C  Downtown Toronto
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 49          M5H  Downtown Toronto
# 50          M6H      West Toronto
# 58          M5J  Downtown Toronto
# 59          M6J      West Toronto
# 66          M4K      East Toronto
# 67          M5K  Downtown Toronto
# 68          M6K      West Toronto
# 75          M4L      East Toronto
# 76          M5L  Downtown Toronto
# 84          M4M      East Toronto
# 93          M4N   Central Toronto
# 94          M5N   Central Toronto
# 102         M4P   Central Toronto
# 103         M5P   Central Toronto
# 104         M6P      West Toronto
# 111         M4R   Central Toronto
# 112         M5R   Central Toronto
# 113         M6R      West Toronto
# 120         M4S   Central Toronto
# 121         M5S  Downtown Toronto
# 122         M6S      West Toronto
# 129         M4T   Central Toronto
# 130         M5T  Downtown Toronto
# 138         M4V   Central Toronto
# 139         M5V  Downtown Toronto
# 147         M4W  Downtown Toronto
# 148         M5W  Downtown Toronto
# 156         M4X  Downtown Toronto
# 157         M5X  Downtown Toronto
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
#
#                                          Neighbourhood   Latitude  Longitude
# 4                            Regent Park, Harbourfront  43.763573 -79.188711
# 6          Queen's Park, Ontario Provincial Government  43.773136 -79.239476
# 13                            Garden District, Ryerson  43.692657 -79.264848
# 22                                      St. James Town  43.799525 -79.318389
# 30                                         The Beaches  43.786947 -79.385975
# 31                                         Berczy Park  43.757490 -79.374714
# 40                                  Central Bay Street  43.782736 -79.442259
# 41                                            Christie  43.753259 -79.329656
# 49                            Richmond, Adelaide, King  43.737473 -79.464763
# 50                        Dufferin, Dovercourt Village  43.739015 -79.506944
# 58   Harbourfront East, Union Station, Toronto Islands  43.695344 -79.318389
# 59                            Little Portugal, Trinity  43.676357 -79.293031
# 66                        The Danforth West, Riverdale  43.679557 -79.352188
# 67            Toronto Dominion Centre, Design Exchange  43.668999 -79.315572
# 68        Brockton, Parkdale Village, Exhibition Place  43.659526 -79.340923
# 75                      India Bazaar, The Beaches West  43.704324 -79.388790
# 76                      Commerce Court, Victoria Hotel  43.689574 -79.383160
# 84                                     Studio District  43.657162 -79.378937
# 93                                       Lawrence Park  43.648198 -79.379817
# 94                                            Roselawn  43.733283 -79.419750
# 102                                   Davisville North  43.653206 -79.400049
# 103    Forest Hill North & West, Forest Hill Road Park  43.628947 -79.394420
# 104                      High Park, The Junction South  43.646435 -79.374846
# 111                  North Toronto West, Lawrence Park  43.693781 -79.428191
# 112                The Annex, North Midtown, Yorkville  43.689026 -79.453512
# 113                             Parkdale, Roncesvalles  43.669542 -79.422564
# 120                                         Davisville  43.713756 -79.490074
# 121                     University of Toronto, Harbord  43.691116 -79.476013
# 122                                 Runnymede, Swansea  43.673185 -79.487262
# 129                        Moore Park, Summerhill East  43.648960 -79.456325
# 130          Kensington Market, Chinatown, Grange Park  43.651571 -79.484450
# 138  Summerhill West, Rathnelly, South Hill, Forest...  43.636966 -79.615819
# 139  CN Tower, King and Spadina, Railway Lands, Har...  43.662744 -79.321558
# 147                                           Rosedale  43.636258 -79.498509
# 148                                     Stn A PO Boxes  43.628841 -79.520999
# 156                        St. James Town, Cabbagetown  43.756303 -79.565963
# 157             First Canadian Place, Underground city  43.724766 -79.532242
# 165                               Church and Wellesley  43.696319 -79.532242
# 168  Business reply mail Processing Centre, South C...  43.688905 -79.554724

# %% [markdown]
# Create a map of Toronto with neiborhoods superimposed on top

# %%
map_toronto = folium.Map(location = [43.7, -79.4], zoom_start = 11)

for lat, lng, label in zip(toronto['Latitude'], toronto['Longitude'], toronto['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9c0ae5dcc1b84dc49d3b083576274354%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9c0ae5dcc1b84dc49d3b083576274354%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9c0ae5dcc1b84dc49d3b083576274354%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9c0ae5dcc1b84dc49d3b083576274354%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.7%2C%20-79.4%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %% [markdown]
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'ECDYE2EBUK3G2N1TMM5QQ44XVM4WQY4RYXZT3XQSEDSFZ1M4' # your Foursquare ID
CLIENT_SECRET = 'MHIGB1YPMQDPAG05UEJ5THYRQ1UBWFI4QGS1DXJYQXQ2PAQS' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
import requests # library to handle requests
from sklearn.cluster import KMeans # import k-means from clustering stage

# %% [markdown]
# Create a function to repeat the same process to all the neighborhoods in Toronto to get nearby venues info

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Create a new dataframe called toronto_venues to save retrieved info

# %%
toronto_venues = getNearbyVenues(names=toronto['Neighbourhood'],
                                   latitudes=toronto['Latitude'],
                                   longitudes=toronto['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
print(toronto_venues.shape)
# Out:
# (736, 7)

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                           Neighborhood  Neighborhood Latitude  \
# 0                            Regent Park, Harbourfront              43.763573
# 1                            Regent Park, Harbourfront              43.763573
# 2                            Regent Park, Harbourfront              43.763573
# 3                            Regent Park, Harbourfront              43.763573
# 4                            Regent Park, Harbourfront              43.763573
# ..                                                 ...                    ...
# 731                               Church and Wellesley              43.696319
# 732                               Church and Wellesley              43.696319
# 733                               Church and Wellesley              43.696319
# 734  Business reply mail Processing Centre, South C...              43.688905
# 735  Business reply mail Processing Centre, South C...              43.688905
#
#      Neighborhood Longitude                  Venue  Venue Latitude  \
# 0                -79.188711         RBC Royal Bank       43.766790
# 1                -79.188711      G & G Electronics       43.765309
# 2                -79.188711             Sail Sushi       43.765951
# 3                -79.188711       Big Bite Burrito       43.766299
# 4                -79.188711  Enterprise Rent-A-Car       43.764076
# ..                      ...                    ...             ...
# 731              -79.532242         2 Bros Cuisine       43.692499
# 732              -79.532242     Dixon & Royal York       43.700013
# 733              -79.532242              Dollarama       43.691945
# 734              -79.554724                 Subway       43.692936
# 735              -79.554724                 Rogers       43.692620
#
#      Venue Longitude             Venue Category
# 0         -79.191151                       Bank
# 1         -79.191537          Electronics Store
# 2         -79.191275                 Restaurant
# 3         -79.190720         Mexican Restaurant
# 4         -79.193406        Rental Car Location
# ..               ...                        ...
# 731       -79.531698  Middle Eastern Restaurant
# 732       -79.534408               Intersection
# 733       -79.531593             Discount Store
# 734       -79.557351             Sandwich Place
# 735       -79.557402          Mobile Phone Shop
#
# [736 rows x 7 columns]

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 194 uniques categories.

# %% [markdown]
# Analyze each neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %% [markdown]
# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.shape
# Out:
# (39, 194)

# %% [markdown]
# Create a function to sort the venues in descending order

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 0, 0, 0, 0, 2, 0, 0, 0, 0], dtype=int32)

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#    Postal Code           Borough                                Neighbourhood  \
# 4          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 6          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 13         M5B  Downtown Toronto                     Garden District, Ryerson
# 22         M5C  Downtown Toronto                               St. James Town
# 30         M4E      East Toronto                                  The Beaches
#
#      Latitude  Longitude  Cluster Labels  1st Most Common Venue  \
# 4   43.763573 -79.188711               0      Electronics Store
# 6   43.773136 -79.239476               0     Athletics & Sports
# 13  43.692657 -79.264848               0  General Entertainment
# 22  43.799525 -79.318389               0            Supermarket
# 30  43.786947 -79.385975               0    Japanese Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 4           Intersection        Breakfast Spot                  Bank
# 6        Thai Restaurant                  Bank  Caribbean Restaurant
# 13                  Café          Skating Rink       College Stadium
# 22           Coffee Shop        Sandwich Place    Chinese Restaurant
# 30    Chinese Restaurant                  Bank                  Café
#
#          5th Most Common Venue 6th Most Common Venue  \
# 4                   Restaurant    Mexican Restaurant
# 6          Fried Chicken Joint      Hakka Restaurant
# 13  Construction & Landscaping          Dessert Shop
# 22              Cosmetics Shop              Pharmacy
# 30               Women's Store      Department Store
#
#           7th Most Common Venue        8th Most Common Venue  \
# 4           Rental Car Location               Medical Center
# 6                   Gas Station                       Bakery
# 13            Electronics Store  Eastern European Restaurant
# 22                  Pizza Place               Breakfast Spot
# 30  Eastern European Restaurant          Dumpling Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 4       Department Store                Dog Run
# 6    Distribution Center         Discount Store
# 13   Dumpling Restaurant       Doner Restaurant
# 22  Fast Food Restaurant                   Bank
# 30      Doner Restaurant                Dog Run

# %% [markdown]
# Visualize the resulting clusters

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[43.7, -79.4], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f06febc7fd724f4e98b646320cf2174b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f06febc7fd724f4e98b646320cf2174b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f06febc7fd724f4e98b646320cf2174b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f06febc7fd724f4e98b646320cf2174b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.7%2C%20-79.4%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...
